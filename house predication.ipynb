# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
house = pd.read_csv("C:/Users/HP/Downloads/house_price.csv")
house
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
house.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
house1 = house.copy()

# %%
# numerical_var = df_house_price.dtypes[df_house_price.dtypes != "object"].index
# data_num = df_house_price[numerical_var]

# %%
#missing data
total_missing_value = house.isnull().sum().sort_values(ascending=False)
percent_of_missign_value = (house.isnull().sum()/house.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total_missing_value, percent_of_missign_value], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#               Total   Percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageYrBlt      81  0.055479
# GarageCond       81  0.055479
# GarageType       81  0.055479
# GarageFinish     81  0.055479
# GarageQual       81  0.055479
# BsmtFinType2     38  0.026027
# BsmtExposure     38  0.026027
# BsmtQual         37  0.025342
# BsmtCond         37  0.025342
# BsmtFinType1     37  0.025342
# MasVnrArea        8  0.005479
# MasVnrType        8  0.005479
# Electrical        1  0.000685
# Id                0  0.000000

# %%
# pd.set_option('display.max_rows',500)

# %%
house1['PoolQC'].value_counts()
# Out:
# Gd    3
# Fa    2
# Ex    2
# Name: PoolQC, dtype: int64

# %%
house1['PoolQC'].fillna('none', inplace = True)

# %%
house1['PoolQC'].value_counts()
# Out:
# none    1453
# Gd         3
# Fa         2
# Ex         2
# Name: PoolQC, dtype: int64

# %%
house1['MiscFeature'].value_counts(dropna=False)
# Out:
# NaN     1406
# Shed      49
# Othr       2
# Gar2       2
# TenC       1
# Name: MiscFeature, dtype: int64

# %%
house1['MiscFeature'].fillna('no features', inplace = True)

# %%
house1['Alley'].value_counts(dropna=False)
# Out:
# NaN     1369
# Grvl      50
# Pave      41
# Name: Alley, dtype: int64

# %%
house1['Alley'].fillna('no alley', inplace = True)

# %%
house1['Fence'].value_counts(dropna=False)
# Out:
# NaN      1179
# MnPrv     157
# GdPrv      59
# GdWo       54
# MnWw       11
# Name: Fence, dtype: int64

# %%
house1['Fence'].fillna('no fence', inplace = True)

# %%
house1['FireplaceQu'].value_counts(dropna=False)
# Out:
# NaN    690
# Gd     380
# TA     313
# Fa      33
# Ex      24
# Po      20
# Name: FireplaceQu, dtype: int64

# %%
house1['FireplaceQu'].fillna('no fireplace', inplace = True)

# %%
house1['GarageQual'].fillna(0, inplace = True)

# %%
house1['GarageQual'].fillna(0, inplace = True)

# %%
house1['GarageQual'].fillna(0, inplace = True)

# %%
house1['LotFrontage'].value_counts(dropna=False)
# Out:
# NaN      259
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
#         ...
# 111.0      1
# 141.0      1
# 112.0      1
# 152.0      1
# 144.0      1
# Name: LotFrontage, Length: 111, dtype: int64

# %%
aa = house1.groupby('Neighborhood')['LotFrontage'].mean().index
aa
# Out:
# Index(['Blmngtn', 'Blueste', 'BrDale', 'BrkSide', 'ClearCr', 'CollgCr',
#        'Crawfor', 'Edwards', 'Gilbert', 'IDOTRR', 'MeadowV', 'Mitchel',
#        'NAmes', 'NPkVill', 'NWAmes', 'NoRidge', 'NridgHt', 'OldTown', 'SWISU',
#        'Sawyer', 'SawyerW', 'Somerst', 'StoneBr', 'Timber', 'Veenker'],
#       dtype='object', name='Neighborhood')

# %%
house1["LotFrontage"] = house1.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))

# %%
house1['GarageCond'].value_counts(dropna=False)
# Out:
# TA     1326
# NaN      81
# Fa       35
# Gd        9
# Po        7
# Ex        2
# Name: GarageCond, dtype: int64

# %%
house1['GarageFinish'].fillna(0, inplace = True)

# %%
house1['MasVnrType'].fillna('None', inplace = True)

# %%
house1['Electrical'].fillna(0, inplace = True)

# %%
for i in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    house1[i] = house1[i].fillna('None')

# %%
house1['MasVnrArea'].fillna(0, inplace = True)

# %%
house1['GarageType'].fillna(0, inplace = True)

# %%
total_missing_value = house1.isnull().sum().sort_values(ascending=False)
percent_of_missign_value = (house1.isnull().sum()/house1.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total_missing_value, percent_of_missign_value], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#               Total   Percent
# GarageYrBlt      81  0.055479
# GarageCond       81  0.055479
# GarageFinish      0  0.000000
# GarageType        0  0.000000
# FireplaceQu       0  0.000000
# Fireplaces        0  0.000000
# Functional        0  0.000000
# TotRmsAbvGrd      0  0.000000
# KitchenQual       0  0.000000
# KitchenAbvGr      0  0.000000
# Id                0  0.000000
# HalfBath          0  0.000000
# FullBath          0  0.000000
# BsmtHalfBath      0  0.000000
# BsmtFullBath      0  0.000000
# GrLivArea         0  0.000000
# LowQualFinSF      0  0.000000
# 2ndFlrSF          0  0.000000
# 1stFlrSF          0  0.000000
# BedroomAbvGr      0  0.000000

# %%
house1.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1460.0      70.199658     22.431902     21.0      60.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1460.0     103.117123    180.731373      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %%
house1['MSSubClass'] = house1['MSSubClass'].apply(str)

# %%
house1.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# LotFrontage    1460.0      70.199658     22.431902     21.0      60.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1460.0     103.117123    180.731373      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# ...

# %%
house1['OverallQual'] = house1['OverallQual'].apply(str)

# %%
house1['OverallCond'] = house1['OverallCond'].apply(str)

# %%
house1['YearBuilt'] = house1['YearBuilt'].apply(str)

# %%
house1['YearRemodAdd'] = house1['YearRemodAdd'].apply(str)

# %%
house1['HalfBath'] = house1['HalfBath'].apply(str)

# %%
house1['BsmtHalfBath'] = house1['BsmtHalfBath'].apply(str)

# %%
house1['FullBath'] = house1['FullBath'].apply(str)

# %%
house1['BedroomAbvGr'] = house1['BedroomAbvGr'].apply(str)

# %%
house1['KitchenAbvGr'] = house1['KitchenAbvGr'].apply(str)

# %%
house1['TotRmsAbvGrd'] = house1['TotRmsAbvGrd'].apply(str)

# %%
house1['Fireplaces'] = house1['Fireplaces'].apply(str)

# %%
house1['GarageYrBlt'] = house1['GarageYrBlt'].apply(str)

# %%
house1['GarageCars'] = house1['GarageCars'].apply(str)

# %%
house1['MoSold'] = house1['MoSold'].apply(str)

# %%
house1['YrSold'] = house1['YrSold'].apply(str)

# %%
house1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
house1 = house1.drop(['Id'],axis=1)

# %%
numerical_var = house1.dtypes[house1.dtypes != "object"].index
data_num = house1[numerical_var]

# %%
categorical_var = house1.dtypes[house1.dtypes == "object"].index
data_cat = house1[categorical_var]

# %%
data_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LotFrontage    1460 non-null   float64
#  1   LotArea        1460 non-null   int64
#  2   MasVnrArea     1460 non-null   float64
#  3   BsmtFinSF1     1460 non-null   int64
#  4   BsmtFinSF2     1460 non-null   int64
#  5   BsmtUnfSF      1460 non-null   int64
#  6   TotalBsmtSF    1460 non-null   int64
#  7   1stFlrSF       1460 non-null   int64
#  8   2ndFlrSF       1460 non-null   int64
#  9   LowQualFinSF   1460 non-null   int64
#  10  GrLivArea      1460 non-null   int64
#  11  BsmtFullBath   1460 non-null   int64
#  12  GarageArea     1460 non-null   int64
#  13  WoodDeckSF     1460 non-null   int64
#  14  OpenPorchSF    1460 non-null   int64
#  15  EnclosedPorch  1460 non-null   int64
#  16  3SsnPorch      1460 non-null   int64
#  17  ScreenPorch    1460 non-null   int64
# ...

# %%
data_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 59 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   object
#  1   MSZoning       1460 non-null   object
#  2   Street         1460 non-null   object
#  3   Alley          1460 non-null   object
#  4   LotShape       1460 non-null   object
#  5   LandContour    1460 non-null   object
#  6   Utilities      1460 non-null   object
#  7   LotConfig      1460 non-null   object
#  8   LandSlope      1460 non-null   object
#  9   Neighborhood   1460 non-null   object
#  10  Condition1     1460 non-null   object
#  11  Condition2     1460 non-null   object
#  12  BldgType       1460 non-null   object
#  13  HouseStyle     1460 non-null   object
#  14  OverallQual    1460 non-null   object
#  15  OverallCond    1460 non-null   object
#  16  YearBuilt      1460 non-null   object
# ...

# %%
data_cat
# Out:
#      MSSubClass MSZoning Street     Alley LotShape LandContour Utilities  \
# 0            60       RL   Pave  no alley      Reg         Lvl    AllPub
# 1            20       RL   Pave  no alley      Reg         Lvl    AllPub
# 2            60       RL   Pave  no alley      IR1         Lvl    AllPub
# 3            70       RL   Pave  no alley      IR1         Lvl    AllPub
# 4            60       RL   Pave  no alley      IR1         Lvl    AllPub
# ...         ...      ...    ...       ...      ...         ...       ...
# 1455         60       RL   Pave  no alley      Reg         Lvl    AllPub
# 1456         20       RL   Pave  no alley      Reg         Lvl    AllPub
# 1457         70       RL   Pave  no alley      Reg         Lvl    AllPub
# 1458         20       RL   Pave  no alley      Reg         Lvl    AllPub
# 1459         20       RL   Pave  no alley      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... GarageQual GarageCond PavedDrive  \
# ...

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
for c in data_cat.columns:
    label_ec = preprocessing.LabelEncoder() 
    label_ec.fit(list(data_cat[c].values)) 
    data_cat[c] = label_ec.transform(list(data_cat[c].values))
    print("done for ", c)
# Out:
# <ipython-input-64-e1dde342c8d2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cat[c] = label_ec.transform(list(data_cat[c].values))
# done for  MSSubClass
# done for  MSZoning
# done for  Street
# done for  Alley
# done for  LotShape
# done for  LandContour
# done for  Utilities
# done for  LotConfig
# done for  LandSlope
# done for  Neighborhood
# done for  Condition1
# done for  Condition2
# done for  BldgType
# done for  HouseStyle
# done for  OverallQual
# done for  OverallCond
# done for  YearBuilt
# done for  YearRemodAdd
# done for  RoofStyle
# done for  RoofMatl
# done for  Exterior1st
# done for  Exterior2nd
# done for  MasVnrType
# done for  ExterQual
# done for  ExterCond
# done for  Foundation
# done for  BsmtQual
# ...

# %%
data_cat
# Out:
#       MSSubClass  MSZoning  Street  Alley  LotShape  LandContour  Utilities  \
# 0              9         3       1      2         3            3          0
# 1              4         3       1      2         3            3          0
# 2              9         3       1      2         0            3          0
# 3             10         3       1      2         0            3          0
# 4              9         3       1      2         0            3          0
# ...          ...       ...     ...    ...       ...          ...        ...
# 1455           9         3       1      2         3            3          0
# 1456           4         3       1      2         3            3          0
# 1457          10         3       1      2         3            3          0
# 1458           4         3       1      2         3            3          0
# 1459           4         3       1      2         3            3          0
#
# ...

# %%
data_num.describe(percentiles=[0.01, 0.02, 0.05, 0.1, 0.25, 0.5, 0.75,0.85, 0.90,0.92, 0.95, 0.97, 0.98, 0.99]).T
# Out:
#                 count           mean           std      min        1%  \
# LotFrontage    1460.0      70.199658     22.431902     21.0     21.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0   1680.00
# MasVnrArea     1460.0     103.117123    180.731373      0.0      0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0      0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0      0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0      0.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0      0.00
# 1stFlrSF       1460.0    1162.626712    386.587738    334.0    520.00
# 2ndFlrSF       1460.0     346.992466    436.528436      0.0      0.00
# LowQualFinSF   1460.0       5.844521     48.623081      0.0      0.00
# GrLivArea      1460.0    1515.463699    525.480383    334.0    692.18
# BsmtFullBath   1460.0       0.425342      0.518911      0.0      0.00
# ...

# %%
X = pd.concat([data_cat,data_num], axis=1)

# %%
data_cat
# Out:
#       MSSubClass  MSZoning  Street  Alley  LotShape  LandContour  Utilities  \
# 0              9         3       1      2         3            3          0
# 1              4         3       1      2         3            3          0
# 2              9         3       1      2         0            3          0
# 3             10         3       1      2         0            3          0
# 4              9         3       1      2         0            3          0
# ...          ...       ...     ...    ...       ...          ...        ...
# 1455           9         3       1      2         3            3          0
# 1456           4         3       1      2         3            3          0
# 1457          10         3       1      2         3            3          0
# 1458           4         3       1      2         3            3          0
# 1459           4         3       1      2         3            3          0
#
# ...

# %%
data_num
# Out:
#       LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0          65.000     8450     196.000         706           0        150
# 1          80.000     9600       0.000         978           0        284
# 2          68.000    11250     162.000         486           0        434
# 3          60.000     9550       0.000         216           0        540
# 4          84.000    14260     350.000         655           0        490
# ...           ...      ...         ...         ...         ...        ...
# 1455       62.000     7917       0.000           0           0        953
# 1456       85.000    13175     119.000         790         163        589
# 1457       66.000     9042       0.000         275           0        877
# 1458       68.000     9717       0.000          49        1029          0
# 1459       75.000     9937       0.000         830         290        136
#
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  ...  BsmtFullBath  \
# ...

# %%
X
# Out:
#       MSSubClass  MSZoning  Street  Alley  LotShape  LandContour  Utilities  \
# 0              9         3       1      2         3            3          0
# 1              4         3       1      2         3            3          0
# 2              9         3       1      2         0            3          0
# 3             10         3       1      2         0            3          0
# 4              9         3       1      2         0            3          0
# ...          ...       ...     ...    ...       ...          ...        ...
# 1455           9         3       1      2         3            3          0
# 1456           4         3       1      2         3            3          0
# 1457          10         3       1      2         3            3          0
# 1458           4         3       1      2         3            3          0
# 1459           4         3       1      2         3            3          0
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
# standardized the dataset
sc_x = StandardScaler()  
sc_x_fit=sc_x.fit(X)
X_std = sc_x_fit.transform(X)

# %%
X_std1=pd.DataFrame(X_std, columns=X.columns)

# %%
X_std1
# Out:
#       MSSubClass  MSZoning  Street  Alley  LotShape  LandContour  Utilities  \
# 0          0.786    -0.046   0.064  0.245     0.751        0.315     -0.026
# 1         -0.625    -0.046   0.064  0.245     0.751        0.315     -0.026
# 2          0.786    -0.046   0.064  0.245    -1.379        0.315     -0.026
# 3          1.069    -0.046   0.064  0.245    -1.379        0.315     -0.026
# 4          0.786    -0.046   0.064  0.245    -1.379        0.315     -0.026
# ...          ...       ...     ...    ...       ...          ...        ...
# 1455       0.786    -0.046   0.064  0.245     0.751        0.315     -0.026
# 1456      -0.625    -0.046   0.064  0.245     0.751        0.315     -0.026
# 1457       1.069    -0.046   0.064  0.245     0.751        0.315     -0.026
# 1458      -0.625    -0.046   0.064  0.245     0.751        0.315     -0.026
# 1459      -0.625    -0.046   0.064  0.245     0.751        0.315     -0.026
#
# ...

# %%
from sklearn.decomposition import PCA 
# create instance for pca
sklearn_pca = PCA()
# fit and transform the instance on datad
sklearn_pca_fit=sklearn_pca.fit(X_std1)
pca_result=sklearn_pca_fit.transform(X_std1)

# %%
pd.DataFrame(pca_result, columns=['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11','PC12','PC13','PC14','PC15','PC16','PC17','PC18','PC19','PC20','PC21','PC22','PC23','PC24','PC25','PC26','PC27','PC28','PC29','PC30','PC31','PC32','PC33','PC34','PC35','PC36','PC37','PC38','PC39','PC40','PC41','PC42','PC43','PC44','PC45','PC46','PC47','PC48','PC49','PC50','PC51','PC52','PC53','PC54','PC55','PC56','PC57','PC58','PC59','PC60','PC61','PC62','PC63','PC64','PC65','PC66','PC67','PC68','PC69','PC70','PC71','PC72','PC73','PC74','PC75','PC76','PC77','PC78','PC79','PC80'
])
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0     1.967172 -1.029648 -1.547134 -2.202366  1.178882 -0.570557  0.918010
# 1     0.301605 -0.232428  2.081904 -0.491808 -0.131976 -0.441767 -0.708605
# 2     2.685514 -0.351997 -1.361797 -1.933645  1.095886 -1.027094  0.476290
# 3    -1.340541  2.370522 -0.348266 -0.595077 -1.030167 -1.299511  1.437982
# 4     4.792851  1.048183 -0.909258 -1.921637  0.755269 -0.732646  0.349519
# ...        ...       ...       ...       ...       ...       ...       ...
# 1455  0.902409 -0.547915 -3.147040 -1.271395  0.015349 -0.942417 -0.683299
# 1456  1.131093  1.021373  3.151634  0.761217 -0.597077  0.077933 -0.567341
# 1457  1.082194  2.689007 -1.249710 -0.616492  1.455205 -0.820390 -0.940556
# 1458 -2.878925 -0.482388  3.225149  0.379620 -0.111576 -0.213201  0.759844
# 1459 -1.126899 -0.538699  2.956382 -0.879144  1.805205 -0.043285 -0.262725
#
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

pd.DataFrame(sklearn_pca_fit.explained_variance_).head(27)
# Out:
#         0
# 0  10.432
# 1   3.940
# 2   3.900
# 3   2.886
# 4   2.690
# 5   2.178
# 6   1.994
# 7   1.946
# 8   1.819
# 9   1.733
# 10  1.699
# 11  1.603
# 12  1.470
# 13  1.417
# 14  1.372
# 15  1.348
# 16  1.228
# 17  1.173
# 18  1.157
# 19  1.154
# 20  1.126
# 21  1.107
# 22  1.068
# 23  1.057
# 24  1.036
# 25  1.019
# 26  0.988

# %%
var=pd.concat([pd.DataFrame(sklearn_pca_fit.explained_variance_), pd.DataFrame(sklearn_pca_fit.explained_variance_ratio_),pd.DataFrame(sklearn_pca_fit.explained_variance_ratio_).cumsum(axis=0) ], axis=1)
var.columns=["eigen","Ratio", "Ratio_Cum"]
var.to_csv("C:/Users/HP/Downloads/house_1.csv")

# %%
pcs32=PCA(n_components=32)
pcs32_fit=pcs32.fit(X_std1)
X_pcs=pcs32_fit.transform(X_std1)

# %%
pc_X = pd.DataFrame(X_pcs, columns=['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11','PC12','PC13','PC14','PC15','PC16','PC17','PC18','PC19','PC20','PC21','PC22','PC23','PC24','PC25','PC26','PC27','PC28','PC29','PC30','PC31','PC32'])

# %%
y = house1['SalePrice']

# %%
from sklearn.linear_model import LinearRegression

# %%
Lr = LinearRegression()
Lr.fit(pc_X,y)
# Out:
# LinearRegression()

# %%
Lr.score(pc_X,y)
# Out:
# 0.8572032004287287
